# %%
import os
import pandas as pd
#import sqlalchemy
import numpy as np

from utils import *

from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# # Lectura de datos del SII

# %%
data_path = os.getcwd() + "/Datos/Detalle_Cat_y_Rol_Cobro"

# %%
with open(data_path + "/BRTMPNACROL_NAC_2018_1", "rb") as file:
    i=0
    for line in file.readlines():
        print(line)
        if i > 3:
            break
        i+=1
# Out:
# b'0110120181       M LIRA 315                              0000100004N00000000000000000001748932160000001748932162055UO\r\n'
# b'0110120181       M LIRA 315                              0000100005N00000000000000000000775787800000000775787802055UO\r\n'
# b'0110120181       M LIRA S/N TERMINAL PESQUERO            0000100008N00000027192850000010695362860000000000000000000UC\r\n'
# b'0110120181A      M LIRA S/N EXPL TERM PESQUERO           0000100017N00000000416680000000129411160000000000000000000UV\r\n'
# b'0110120181       CDTE SAN MARTIN 141 2 DO PISO           0000200004N00000000000000000002704667150000002704667152055UO\r\n'

# %%
# %%time
df = pd.DataFrame()
df_dict = {}
limit = 10000000
with open(data_path + "/BRTMPNACROL_NAC_2018_1", "r") as file:
    i=0
    for line in file.readlines():
        line = line#.decode('utf-8')
        data = get_register_from_line_custom(line.replace("\n",""))
        codigo_destino = data[-1]
        
        if codigo_destino == "H":
            df_dict[i] = data
            i+=1
    
        if i >= limit:
            break
# Out:
# CPU times: total: 43 s
# Wall time: 47.5 s

# %%
columns = ["comuna_actual", "año", "semestre", "indicador_de_aseo",
           #"direccion_predial", "manzana_actual", "predio_actual",
           "codigo_de_serie", "cuota_trimestral", "avaluo_total", 
           "avaluo_exento", #"año_termino_exencion", 
           "codigo_ubicacion",
           "codigo_destino"]

df = pd.DataFrame.from_dict(df_dict, orient='index', columns=columns)
df.head()
# Out:
#    comuna_actual   año  semestre indicador_de_aseo codigo_de_serie  \
# 0           1101  2018         1                                 N
# 1           1101  2018         1                                 N
# 2           1101  2018         1                                 N
# 3           1101  2018         1                                 N
# 4           1101  2018         1                 A               N
#
#    cuota_trimestral  avaluo_total  avaluo_exento codigo_ubicacion  \
# 0                 0      19765645       19765645                U
# 1                 0      10867513       10867513                U
# 2                 0      32758107       32758107                U
# 3                 0      15719344       15719344                U
# 4             17576      46874223       33199976                U
#
#   codigo_destino
# 0              H
# 1              H
# 2              H
# 3              H
# 4              H

# %%
corte = 169144585
exento = 47360490
tasa_1 = 0.00893
tasa_2 = 0.01042

df["avaluo_afecto"] = df["avaluo_total"] - df["avaluo_exento"]
df["contribucion_total"] = df["cuota_trimestral"]*2
# caso a: 
df["impuesto_territorial"] = np.where(df["avaluo_total"] <= exento, 0, np.nan)
# caso b:
df["impuesto_territorial"] = np.where((df["avaluo_total"] > exento)&(df["avaluo_total"] <= corte), 
                                      tasa_1*df["avaluo_afecto"]/2,
                                      np.nan)

df["derechos_aseo"] = df["contribucion_total"] - df["impuesto_territorial"]
df[abs(df["derechos_aseo"])<1].round(2)
# Out:
#          comuna_actual   año  semestre indicador_de_aseo codigo_de_serie  \
# 32                1101  2018         1                                 N
# 424               1101  2018         1                                 N
# 428               1101  2018         1                                 N
# 475               1101  2018         1                                 N
# 747               1101  2018         1                                 N
# ...                ...   ...       ...               ...             ...
# 5078402          16403  2018         1                                 N
# 5085267          16403  2018         1                                 N
# 5092384          16404  2018         1                                 N
# 5102533          16404  2018         1                                 N
# 5102818          16404  2018         1                                 N
#
#          cuota_trimestral  avaluo_total  avaluo_exento codigo_ubicacion  \
# ...

# %%
df["impuesto_territorial"] = np.where(df["avaluo_afecto"] == 0,# caso a
                                      0,
                                      np.where((0 < df["avaluo_afecto"])&(df["avaluo_total"] <= corte), #caso b
                                               tasa_1*(df["avaluo_afecto"])/2,
                                               np.where(df["avaluo_total"] > corte, # caso c
                                                        tasa_1*(corte - df["avaluo_exento"]) + tasa_2*(df["avaluo_total"] - corte)/2,
                                                        np.nan)
                                              )
                                     )

# %% [markdown]
# # Lectura archivos Excel

# %%
data_path = os.getcwd() + "\\Datos"

# %%
# check que la estructura de datos que se cargan de los 3 archivos es la misma
df1 = pd.read_excel(data_path + "\\ingresos_y_gastos_municipales_2014.xlsx", skiprows=1, engine='openpyxl')
df2 = pd.read_excel(data_path + "\\ingresos_y_gastos_municipales_2018.xlsx", skiprows=1, engine='openpyxl')
df3 = pd.read_excel(data_path + "\\ingresos_y_gastos_municipales_2022.xlsx", skiprows=1, engine='openpyxl')
        
check_data(df1, df2, df3)

columns = [val for val in mapper.values()]
df = pd.DataFrame(columns=columns)

for i, item in enumerate(zip([df1,df2,df3], [2014,2018,2022])):
    year = item[1]
    try:
        item[0].drop(0, inplace=True)
    except:
        None
        
    item[0].loc[:,"Año"] = year
    item[0].rename(mapper=mapper, axis=1, inplace=True)
    
    df = pd.concat([df, item[0]])
    df.reset_index(drop=True, inplace=True)

df["Codigo"] = df["Codigo"].astype(str).str.zfill(5)
df["Codigo Region"] = df["Codigo"].str[:2]
df["Codigo Provincia"] = df["Codigo"].str[:3]

for col in df.columns:
    if col[:3] == "IAD" or col[:3] == "BGM":
        df[col] = pd.to_numeric(df[col], downcast="float", errors="coerce")

df.head()
# Out:
# Las columnas coinciden
# Las filas coinciden
#
# Todo OK. Seguimos
#   Codigo      Municipio  IADM83    IADM97    IADM98    IADM99       IADM10  \
# 0  01101        IQUIQUE     0.0  959868.0  323144.0  636724.0   230.289993
# 1  01107  ALTO HOSPICIO     0.0   78971.0   52012.0   26959.0   110.949997
# 2  01401   POZO ALMONTE     0.0    5622.0    4072.0    1550.0   440.190002
# 3  01402         CAMIÑA     0.0     256.0     256.0       0.0  1344.050049
# 4  01403       COLCHANE     0.0    1020.0     127.0     893.0  1283.619995
#
#      IADM140      IADM01     IADM999  ...  BGMAPCUL  BGMAPREC   BGMAPSOC  \
# 0  5238434.0  45237600.0  45237600.0  ...  788763.0  756513.0  1500903.0
# 1   311312.0  11769172.0  11769172.0  ...       0.0       0.0   118801.0
# 2   193277.0   6040675.0   6040665.0  ...   57935.0   64100.0   215072.0
# 3       93.0   1743232.0   1743232.0  ...   78167.0    4408.0     7942.0
# 4      723.0   2179584.0   2179584.0  ...       0.0       0.0        0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Codigo            1035 non-null   object
#  1   Municipio         1035 non-null   object
#  2   IADM83            1032 non-null   float32
#  3   IADM97            1032 non-null   float32
#  4   IADM98            1032 non-null   float32
#  5   IADM99            1032 non-null   float32
#  6   IADM10            1032 non-null   float32
#  7   IADM140           1032 non-null   float32
#  8   IADM01            1032 non-null   float32
#  9   IADM999           1032 non-null   float32
#  10  IADM40            1032 non-null   float32
#  11  IADM44            1032 non-null   float32
#  12  IADM121           1032 non-null   float32
#  13  IADM122           1032 non-null   float32
#  14  IADM43            1032 non-null   float32
#  15  IADM43.1          1032 non-null   float32
# ...

# %%
# IPP = 'IADM41',  IT = 'IADM140'
# Cálculo del porcentaje que representa el Impuesto Territorial (IT) en los Ingresos Propios Permanentes (PP)
df["%IT_en_IPP"] = 100.0*df['IADM140']/df['IADM41']

# %%
df_groupped = df[["Año","Codigo Region","%IT_en_IPP"]].groupby(by=["Año","Codigo Region"]).mean()["%IT_en_IPP"]
for year in [2014, 2018, 2022]:
    df_to_plot = df_groupped[year].reset_index(drop=False)
    fig = px.bar(df_to_plot, x="Codigo Region", y="%IT_en_IPP")
    fig.update_layout(title=dict(text=f"{year}", x=0.5, xanchor="center"),
                     height=300)
    fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Codigo            1035 non-null   object
#  1   Municipio         1035 non-null   object
#  2   IADM83            1032 non-null   float32
#  3   IADM97            1032 non-null   float32
#  4   IADM98            1032 non-null   float32
#  5   IADM99            1032 non-null   float32
#  6   IADM10            1032 non-null   float32
#  7   IADM140           1032 non-null   float32
#  8   IADM01            1032 non-null   float32
#  9   IADM999           1032 non-null   float32
#  10  IADM40            1032 non-null   float32
#  11  IADM44            1032 non-null   float32
#  12  IADM121           1032 non-null   float32
#  13  IADM122           1032 non-null   float32
#  14  IADM43            1032 non-null   float32
#  15  IADM43.1          1032 non-null   float32
# ...

# %%
df_group_region = df[["Año","Codigo Region","%IT_en_IPP"]].groupby(by=["Año","Codigo Region"]).mean()["%IT_en_IPP"]
df_group_by_comuna = df[["Año","Codigo Region", "Municipio", "%IT_en_IPP"]].groupby(
    by=["Año", "Codigo Region", "Municipio"]
).mean()["%IT_en_IPP"].to_frame()

for year in [2014, 2018, 2022]:
    for region in df["Codigo Region"].unique():
        promedio_region = df_group_region[(year, region)] #de %IT_en_IPP
        df_group_by_comuna.loc[(year, region),"diff_region"] = df_group_by_comuna.loc[(year, region)]["%IT_en_IPP"].values - promedio_region

# %%
df_group_by_comuna
# Out:
#                                     %IT_en_IPP  diff_region
# Año    Codigo Region Municipio
# 2014.0 01            ALTO HOSPICIO   10.025127     3.189222
#                      CAMIÑA           0.093588    -6.742317
#                      COLCHANE         0.543021    -6.292884
#                      HUARA            0.586803    -6.249102
#                      IQUIQUE         20.125586    13.289680
# ...                                        ...          ...
# 2022.0 16            SAN IGNACIO     16.983931    -8.862526
#                      SAN NICOLÁS     11.751087   -14.095369
#                      TREHUACO        13.997507   -11.848949
#                      YUNGAY          39.447876    13.601419
#                      ÑIQUÉN          20.463358    -5.383099
#
# [1035 rows x 2 columns]

# %%
regions = df_group_by_comuna.reset_index()["Codigo Region"].unique()
years = [2014, 2018, 2022]
for region in regions: 
    fig = make_subplots(rows=1, cols=len(years), shared_yaxes=True)
    for i, year in enumerate(years):
        pomedio_region = df_group_region[(year, region)]
        fig.add_trace(go.Bar(name=f"{year}",
                             x=df_group_by_comuna.loc[(year, region)].reset_index()["Municipio"],
                             y=df_group_by_comuna.loc[(year, region)].reset_index()["%IT_en_IPP"]),
                     row=1, col=i+1)
        fig.add_hline(y=pomedio_region, row=1, col=i+1)
        fig.update_layout(title=dict(text=f"{region_dict[region]}", x=0.5, xanchor="center"),
                         height=400)
    fig.show()

# %%
# IPP = 'IADM41',  IT = 'IADM140'
# Cálculo del porcentaje que representa el Impuesto Territorial (IT) en los Ingresos Propios Permanentes (PP)
df["IDDAA"] = df['IADM97'] + df["IADM98"] + df["IADM99"]

# %%
# !pip freeze
# Out:
# anyio==4.0.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.4.0
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.0.0
# certifi==2023.7.22
# cffi==1.15.1
# charset-normalizer==3.2.0
# colorama==0.4.6
# comm==0.1.4
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# et-xmlfile==1.1.0
# exceptiongroup==1.1.3
# executing==1.2.0
# fastjsonschema==2.18.0
# fqdn==1.5.1
# idna==3.4
# importlib-metadata==6.8.0
# importlib-resources==6.1.0
# ipykernel==6.25.2
# ipython==8.12.2
# ipython-genutils==0.2.0
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.0
# Jinja2==3.1.2
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.19.1
# jsonschema-specifications==2023.7.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.7.0
# jupyter-lsp==2.2.0
# jupyter_client==8.3.1
# jupyter_core==5.3.1
# jupyter_server==2.7.3
# jupyter_server_terminals==0.4.4
# jupyterlab==4.0.6
# ...
